# %%
from dotenv import load_dotenv
import os
import requests
import pandas as pd
import numpy as np
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("COINGEKO_KEY")

def fetch_market_data():
    headers = {
        "Accept": "application/json",
        "X-CoinGecko-Api-Key": API_KEY
    }
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        "vs_currency": "usd",
        "order": "market_cap_desc",
        "per_page": 100,
        "page": 1,
        "sparkline": "false",
        "price_change_percentage": "24h,7d"
    }
    data = requests.get(url, params=params, headers=headers).json()
    # df = pd.DataFrame(data)
    return data
    return df[["id", "symbol", "current_price", "market_cap", "total_volume", "price_change_percentage_24h", "price_change_percentage_7d_in_currency"]]

# %%
parameters = {
         'vs_currency': 'usd',
         'order': 'market_cap_desc',
         'per_page': 100,
         'page': 1,
         'sparkline': False,
         'locale': 'en'
         }

# %%
data = fetch_market_data()

# %%
data[:2]
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 110924,
#   'market_cap': 2213522035158,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 2213522035158,
#   'total_volume': 66569708442,
#   'high_24h': 113407,
#   'low_24h': 110392,
#   'price_change_24h': -1523.5145645956654,
#   'price_change_percentage_24h': -1.35486,
#   'market_cap_change_24h': -25534548172.381348,
#   'market_cap_change_percentage_24h': -1.14042,
#   'circulating_supply': 19934406.0,
#   'total_supply': 19934406.0,
#   'max_supply': 21000000.0,
#   'ath': 126080,
#   'ath_change_percentage': -11.53329,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 67.81,
#   'atl_change_percentage': 164389.5593,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-10-16T04:48:52.096Z',
#   'price_change_percentage_24h_in_currency': -1.3548647937826395,
#   'price_change_percentage_7d_in_currency': -8.775067946596806},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 3999.46,
#   'market_cap': 483738716241,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 483738716241,
#   'total_volume': 43050557343,
#   'high_24h': 4203.8,
#   'low_24h': 3944.17,
#   'price_change_24h': -120.02716773939619,
#   'price_change_percentage_24h': -2.91364,
#   'market_cap_change_24h': -12056146503.228882,
#   'market_cap_change_percentage_24h': -2.43168,
#   'circulating_supply': 120698786.3547597,
#   'total_supply': 120698786.3547597,
#   'max_supply': None,
#   'ath': 4946.05,
#   'ath_change_percentage': -18.66224,
#   'ath_date': '2025-08-24T19:21:03.333Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 929045.8614,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 47.2083132453005,
#    'currency': 'btc',
#    'percentage': 4720.831324530051},
#   'last_updated': '2025-10-16T04:48:44.105Z',
#   'price_change_percentage_24h_in_currency': -2.913643483839922,
#   'price_change_percentage_7d_in_currency': -9.374565329211269}]

# %%
df = pd.DataFrame(data)
df = df[["id", "symbol", "current_price", "market_cap", "total_volume", "price_change_percentage_24h", "price_change_percentage_7d_in_currency"]]

# %%
df.head()
# Out:
#             id symbol  current_price     market_cap  total_volume  \
# 0      bitcoin    btc     110924.000  2213522035158  6.656971e+10
# 1     ethereum    eth       3999.460   483738716241  4.305056e+10
# 2       tether   usdt          1.001   181469922380  1.260384e+11
# 3  binancecoin    bnb       1175.700   164048610039  4.677115e+09
# 4       ripple    xrp          2.420   145046717347  5.138676e+09
#
#    price_change_percentage_24h  price_change_percentage_7d_in_currency
# 0                     -1.35486                               -8.775068
# 1                     -2.91364                               -9.374565
# 2                     -0.00095                                0.047126
# 3                     -2.99446                               -6.862463
# 4                     -2.97720                              -14.580822

# %%
def rank_assets(df):
    df["volume_ratio"] = df["total_volume"] / df["market_cap"]
    df["score"] = (
        0.5 * df["price_change_percentage_7d_in_currency"].fillna(0)
        + 0.3 * df["volume_ratio"]
        - 0.2 * df["price_change_percentage_24h"].abs()
    )
    df = df.sort_values("score", ascending=False)
    return df[["id", "symbol", "score", "current_price"]].head(10)

# %%
recommendations = rank_assets(df)

# %%
recommendations
# Out:
#                                       id   symbol       score  current_price
# 44                         chainopera-ai     coai  135.925407      18.980000
# 43                                 zcash      zec   17.644484     230.490000
# 41                             bittensor      tao    8.351725     400.420000
# 80                           tether-gold     xaut    2.568638    4252.320000
# 96                              pax-gold     paxg    2.535460    4256.570000
# 57                                 c1usd    c1usd    0.265776       1.000000
# 2                                 tether     usdt    0.231735       1.001000
# 75                                hash-2     hash    0.138983       0.035716
# 24  binance-bridged-usdt-bnb-smart-chain  bsc-usd    0.105916       1.000000
# 6                               usd-coin     usdc    0.084314       0.999847
